# %% [markdown]
# <a href="https://colab.research.google.com/github/Dobrydin/Project_1/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
df = pd.read_csv('dst-3.0_16_1_hh_database.csv', sep=';', encoding='utf-8')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
df.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
display(df.describe())
display(df.nunique())
print(df['Ищет работу на должность:'].mode())
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
# Функция для преобразования уровня образования
def extract_education(education_str):
    # Разделяем строку на слова
    words = education_str.split()
    # Проверяем первые два слова и возвращаем соответствующую категорию
    if words[0] == 'Высшее':
        return 'высшее'
    elif words[0] == 'Неоконченное':
        return 'неоконченное высшее'
    elif words[0] == 'Среднее' and words[1] == 'специальное':
        return 'среднее специальное'
    elif words[0] == 'Среднее':
        return 'среднее'
    else:
        return None  # На случай, если уровень образования не соответствует ожидаемым

# Применение функции к столбцу "Образование и ВУЗ"
df['Образование'] = df['Образование и ВУЗ'].apply(extract_education)

# Проверка уникальных значений в новом столбце "Образование"
unique_educations = df['Образование'].unique()
print("Уникальные значения в столбце 'Образование':", unique_educations)

# Удаление старого столбца "Образование и ВУЗ"
df.drop(columns=['Образование и ВУЗ'], inplace=True)

# Вывод результата
display(df.head())
print(df['Образование'].value_counts())
# Out:
# Уникальные значения в столбце 'Образование': ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
# Функция для преобразования строки в пол и возраст
def extract_gender_age(gender_age_str):
    # Разделяем строку по символу ','
    parts = gender_age_str.split(' , ')
    # Извлекаем пол
    gender = 'М' if parts[0] == 'Мужчина' else 'Ж'
    # Извлекаем возраст и преобразуем в целое число
    age = int(parts[1].split()[0])  # Берем первое слово и преобразуем в int
    return gender, age

# Применение функции к столбцу "Пол, возраст"
df[['Пол', 'Возраст']] = df['Пол, возраст'].apply(lambda x: pd.Series(extract_gender_age(x)))

# Проверка уникальных значений в новом столбце "Пол" и "Возраст"
unique_genders = df['Пол'].unique()
unique_ages = df['Возраст'].unique()
print("Уникальные значения в столбце 'Пол':", unique_genders)
print("Уникальные значения в столбце 'Возраст':", unique_ages)

# Удаление старого столбца "Пол, возраст"
df.drop(columns=['Пол, возраст'], inplace=True)

# Вывод результата
display(df.head())
print(df['Пол'].value_counts(normalize=True))
print(df['Возраст'].mean())
# Out:
# Уникальные значения в столбце 'Пол': ['М' 'Ж']
# Уникальные значения в столбце 'Возраст': [ 39  60  36  38  26  29  46  34  35  59  27  21  31  37  30  33  42  32
#   23  28  25  24  43  53  49  44  48  54  22  20  40  62  72  45  41  61
#   50  58  57  52  56  18  19  51  16  47  71  63  55  64  68  17  73  66
#   65  77  67  69  76  70  14  15 100]
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
def convert_experience_to_months(period):

    # Проверяем, является ли переменная строкой, состоит ли она только из букв
    # (например, "Не указано") или равна None. Если да, функция возвращает None
    if not isinstance(period, str):
        return None
    elif period.isalpha():
        return None
    elif period is None:
        return None
    else:
        # Инициализируем переменные
        year, month = 0, 0

        # Проверяем, входят ли ключевые слова в строку
        if period.count('лет') + period.count('год') + period.count('месяц') > 0:

            # Если да разделяем строку на слова по пробелу
            work_list = period.split(' ')

            # В списке перебираем начальные слова и если встретим "год или "лет"
            # предыдущее слово преобразуем в число, умножаем на 12 и присваиваем переменной year.
            # Аналогично находим месяцы
            for i, work in enumerate(work_list[:6]):
                if work.count('лет') + work.count('год') > 0:
                    year = int(work_list[i-1].strip()) * 12
                elif work.count('месяц') > 0:
                    month = int(work_list[i-1].strip())
        return month + year

# Применение функции к столбцу "Опыт работы"
df['Опыт работы (месяц)'] = df['Опыт работы'].apply(convert_experience_to_months)

# Удаление старого столбца "Опыт работы"
df.drop(columns=['Опыт работы'], inplace=True)

# Вывод результата
display(df.info())
print(f'Медианный опыт работы {df["Опыт работы (месяц)"].median()} мес.')
# Out:
# Медианный опыт работы 100.0 мес

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
# Список городов-миллионников
million_cities = [
    'Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань',
    'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону',
    'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград'
]

# Функция для извлечения информации
def extract_info(row):
    # Извлечение города
    parts = row.split(',')
    city = parts[0].strip()  # Первый элемент - это город

    if city in ['Москва', 'Санкт-Петербург']:
        city_category = city
    elif city in million_cities:
        city_category = 'город-миллионник'
    else:
        city_category = 'другие'

    # Заменяем в строке слово "хочу" но "готов"
    row_replaced = row.lower().replace('хочу', 'готов')

    # Проверка готовности к переезду
    ready = row_replaced.split('готов') # Разделяем по слову "готов"
    if ' не ' in ready[0]:
        relocation_ready = False
    else:
        relocation_ready = True

    # Проверка готовности к командировкам
    if len(ready) < 3 or ' не ' in ready[1]: # Если "готов" входит < 2 раз,
    # или перед вторым словом стоит "не", значит к командировкам не готов
        travel_ready = False
    else:
        travel_ready = True

    return pd.Series([city_category, relocation_ready, travel_ready])

# Применение функции к столбцу
df[['Город', 'Готовность к переезду', 'Готовность к командировкам']] = df['Город, переезд, командировки'].apply(extract_info)

# Удаление исходного столбца
df.drop(columns=['Город, переезд, командировки'], inplace=True)

# Проверка уникальных значений для новых признаков
print(df['Город'].unique())
print(df['Готовность к переезду'].unique())
print(df['Готовность к командировкам'].unique())

# Процент соискателей, живущих в Санкт-Петербурге
df['Город'].value_counts(normalize=True)

# Процент соискателей, готовых одновременно и к переездам, и к командировкам
ready_for_both_count = df[(df['Готовность к переезду'] == True) & (df['Готовность к командировкам'] == True)].shape[0] * 100 / df.shape[0]
print(f'Готовы к переезду и командировкам {round(ready_for_both_count)}%')
# Out:
# ['другие' 'Москва' 'город-миллионник' 'Санкт-Петербург']
# [False  True]
# [False  True]
# Готовы к переезду и командировкам 32%

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# Определяем уникальные категории для "Занятость" и "График"
employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
schedule_categories = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']

# Создаем бинарные столбцы для "Занятость"
for category in employment_categories:
    df[category] = df['Занятость'].str.contains(category).astype(bool)

# Создаем бинарные столбцы для "График"
for category in schedule_categories:
    df[category] = df['График'].str.contains(category).astype(bool)

# Удаляем исходные столбцы "Занятость" и "График"
df.drop(columns=['Занятость', 'График'], inplace=True)

# Вывод результата
display(df.head())

# Подсчет людей, ищущих проектную работу и волонтерство
project_and_volunteer_count = df[(df['проектная работа'] == True) & (df['волонтерство'] == True)].shape[0]

# Подсчет людей, желающих работать вахтовым методом и с гибким графиком
shift_and_flexible_count = df[(df['вахтовый метод'] == True) & (df['гибкий график'] == True)].shape[0]

# Вывод результатов
print("Количество людей, ищущих проектную работу и волонтерство:", project_and_volunteer_count)
print("Количество людей, желающих работать вахтовым методом и с гибким графиком:", shift_and_flexible_count)
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
# 2                               Кассир-операционист  16.04.2019 08:35
# 3                               Инженер-программист  08.04.2019 14:23
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
# Загрузка данных о курсах валют
exchange_rates = pd.read_csv('ExchangeRates.csv')

#  Преобразование столбца "Обновление резюме" в формат datetime
df['Обновление резюме'] = pd.to_datetime(df['Обновление резюме'])
df['date'] = df['Обновление резюме'].dt.date


# Извлечение суммы и валюты из столбца "ЗП"
df['salary'] = df['ЗП'].str.split(' ', expand=True)[0].astype(float)
df['currency'] = df['ЗП'].str.split(' ', expand=True)[1].str.replace('.', '')

# Приводим валюты к стандарту ISO
currency_mapping = {
    'руб' : 'RUB',
    'грн' : 'UAH',
    'USD' : 'USD',
    'EUR' : 'EUR',
    'белруб' : 'BYN',
    'KZT' : 'KZT',
    'сум' : 'UZS',
    'AZN' : 'AZN'
}
df['currency'] = df['currency'].replace(currency_mapping)

# Объединение таблиц по дате и валюте
# Приводим дату в exchange_rates к формату datetime
exchange_rates['date'] = pd.to_datetime(exchange_rates['date']).dt.date

# Объединяем таблицы
merged = pd.merge(df, exchange_rates, how='left', left_on=['date', 'currency'], right_on=['date', 'currency'])

# Заполняем курс рубля и пропорцию (1:1)
merged['close'].fillna(1, inplace=True)
merged['proportion'].fillna(1, inplace=True)
# Вычисление "ЗП (руб)"
merged['ЗП (руб)'] = (merged['salary'] * merged['close']) / merged['proportion']
# Удаление исходного столбца "ЗП" и промежуточных столбцов
merged.drop(columns=['ЗП', 'currency', 'salary', 'proportion', 'close', 'per', 'time', 'vol', 'date'], inplace=True)
median_salary = merged['ЗП (руб)'].median()
# Вывод результатов
display(merged.info())
print(f'Желаемая медианная заработная плата соискателей: {round(median_salary / 1000)} тыс. руб')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Последнее/нынешнее место работы  44743 non-null  object
#  2   Последняя/нынешняя должность     44742 non-null  object
#  3   Обновление резюме                44744 non-null  datetime64[ns]
#  4   Авто                             44744 non-null  object
#  5   Образование                      44744 non-null  object
#  6   Пол                              44744 non-null  object
#  7   Возраст                          44744 non-null  int64
#  8   Опыт работы (месяц)              44576 non-null  float64
#  9   Город                            44744 non-null  object
#  10  Готовность к переезду            44744 non-null  bool
#  11  Готовность к командировкам       44744 non-null  bool
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Построение гистограммы и коробчатой диаграммы
plt.figure(figsize=(12, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(merged['Возраст'], bins=10, kde=True)
plt.title('Распределение возраста')
plt.xlabel('Возраст')
plt.ylabel('Частота')

# Коробчатая диаграмма
plt.subplot(1, 2, 2)
sns.boxplot(x=merged['Возраст'])
plt.title('Коробчатая диаграмма возраста')

plt.tight_layout()
plt.show()

# Вычисление статистик
mode_age = merged['Возраст'].mode()[0]  # Мода
min_age = merged['Возраст'].min()        # Минимальное значение
max_age = merged['Возраст'].max()        # Максимальное значение
q1 = merged['Возраст'].quantile(0.25)    # 1-й квартиль
q3 = merged['Возраст'].quantile(0.75)    # 3-й квартиль
iqr = q3 - q1                         # Интерквартильный размах

# Определение предельных значений для выявления аномалий
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Интервал, в котором находится большинство соискателей
majority_age_range = (q1, q3)

# Вывод результатов
print(f"Мода возраста: {mode_age}")
print(f"Предельные значения возраста: {min_age} - {max_age}")
print(f"Возраст большинства соискателей находится в интервале: {majority_age_range}")
print(f"Найдены аномалии: {merged[(merged['Возраст'] < lower_bound) | (merged['Возраст'] > upper_bound)]['Возраст'].value_counts()}")

# Чтобы обосновать последующие выводы, вычислим еще кое-какие показатели
# Вычисление среднего и стандартного отклонения
mean_age = merged['Возраст'].mean()
std_age = merged['Возраст'].std()

# Определение границ
lower_bound = mean_age - 2 * std_age
upper_bound = mean_age + 2 * std_age

# Подсчет количества данных за пределами двух сигм
outliers = merged[(merged['Возраст'] < lower_bound) | (merged['Возраст'] > upper_bound)]
num_outliers = outliers.shape[0]

# Теоретические результаты для нормального распределения
# В нормальном распределении примерно 95% данных находятся в пределах 2 сигм
theoretical_outliers_percentage = 100 * (1 - 0.95)  # 5% выбросов
theoretical_outliers_count = len(merged) * (theoretical_outliers_percentage / 100)

# Вывод результатов
print(f"Средний возраст: {mean_age:.2f}")
print(f"Стандартное отклонение: {std_age:.2f}")
print(f"Нижняя граница (2 сигмы): {lower_bound:.2f}")
print(f"Верхняя граница (2 сигмы): {upper_bound:.2f}")
print(f"Количество выбросов (за пределами 2 сигм): {num_outliers}")
print(f"Теоретическое количество выбросов для нормального распределения: {theoretical_outliers_count:.2f}")
# Out:
# Мода возраста: 30
# Предельные значения возраста: 14 - 100
# Возраст большинства соискателей находится в интервале: (27.0, 36.0)
# Найдены аномалии: Возраст
# 50     240
# 51     217
# 52     186
# 54     186
# 53     169
# 55     137
# 57     131
# 56     120
# 58      86
# 59      72
# 60      59
# 61      38
# 63      29
# 62      22
# 65      20
# 64      17
# 66      11
# 67       9
# 69       4
# 71       4
# 73       4
# 68       4
# 72       3
# 70       3
# 77       1
# 76       1
# 100      1
# Name: count, dtype: int64
# Средний возраст: 32.20
# Стандартное отклонение: 7.93
# Нижняя граница (2 сигмы): 16.34
# Верхняя граница (2 сигмы): 48.06
# Количество выбросов (за пределами 2 сигм): 2067
# Теоретическое количество выбросов для нормального распределения: 2237.20

# %% [markdown]
# # Выводы:
#
# * Распределение соискателей по возрастам близко к нормальному, но поскольку возраст ограничен только слева, на гистограмме имеется асимметрия. Применение лгарифмического преобразования к данным может помочь сделать распределение более симметричным.
# * Как видно из коробчатой диаграммы, все аномалии находятся справа, что также объясняется ограничениями на минимальный возраст.
# * Среди аномальных данных надо обратить внимание на 100-летнего соискателя, скорее всего это недостоверный возраст. Остальные, вероятно не являются следствием ошибочных или недостоверных запмсей, поскольку их количество даже меньше, чем для теоретического нормального распределения.
# * Мода распределения, т. е. самый распространенный возраст: 30 лет.
# * Предельные значения признака, или интервал, в котором находится возраст большинства соискателей 27 - 36 лет.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Построение гистограммы и коробчатой диаграммы
plt.figure(figsize=(12, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(merged[merged['Опыт работы (месяц)'] <= 700]['Опыт работы (месяц)'], bins=10, kde=True)
plt.title('Распределение опыта работы')
plt.xlabel('Опыт работы (месяц)')
plt.ylabel('Частота')

# Коробчатая диаграмма
plt.subplot(1, 2, 2)
sns.boxplot(x=merged['Опыт работы (месяц)'])
plt.title('Коробчатая диаграмма опыта работы')

plt.tight_layout()
plt.show()

# Вычисление статистик
mode_experience = merged['Опыт работы (месяц)'].mode()[0]  # Мода
min_experience = merged['Опыт работы (месяц)'].min()        # Минимальное значение
max_experience = merged['Опыт работы (месяц)'].max()        # Максимальное значение
q1 = merged['Опыт работы (месяц)'].quantile(0.25)            # 1-й квартиль
q3 = merged['Опыт работы (месяц)'].quantile(0.75)            # 3-й квартиль
iqr = q3 - q1                                           # Интерквартильный размах

# Определение предельных значений для выявления аномалий
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Интервал, в котором находится большинство соискателей
majority_experience_range = (q1, q3)

# Вывод результатов
print(f"Мода опыта работы: {mode_experience} месяцев")
print(f"Предельные значения опыта работы: {min_experience} - {max_experience} месяцев")
print(f"Опыт работы большинства соискателей находится в интервале: {majority_experience_range} месяцев")
print(f"Найдены аномалии: {merged[(merged['Опыт работы (месяц)'] < lower_bound) | (merged['Опыт работы (месяц)'] > upper_bound)]['Опыт работы (месяц)'].value_counts()}")
# Out:
# Мода опыта работы: 81.0 месяцев
# Предельные значения опыта работы: 0.0 - 1188.0 месяцев
# Опыт работы большинства соискателей находится в интервале: (57.0, 154.0) месяцев
# Найдены аномалии: Опыт работы (месяц)
# 310.0    26
# 322.0    23
# 313.0    22
# 301.0    22
# 304.0    21
#          ..
# 569.0     1
# 488.0     1
# 530.0     1
# 526.0     1
# 622.0     1
# Name: count, Length: 218, dtype: int64

# %% [markdown]
# # Выводы:
#
# * Мода распределения опытя работы равна 81 мес.
# * Минимальный опыт 0 мес, максимальный - 1188 мес.
# * Опыт большинства соискателей находится в пределах 57 - 154 мес.  опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# * Распределение соискателей по опыту работы напоминает распределение по возрасту, оно тоже асимметрично из-за наличия нижней грани. Однако для того, чтобы построить гистограмму пришлось избавиться от выброса, который портил гистограмму.
# * Речь идет о соискателе с нереально высоким опытом работы (около 99 лет). Это очевидная ошибки, ее можно видеть на коробчатой диаграмме справа. Остальные аномальные данные вполне правдоподобны.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Построение гистограммы и коробчатой диаграммы
plt.figure(figsize=(12, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(merged[merged['ЗП (руб)'] <= 1000000]['ЗП (руб)'], bins=10, kde=True)
plt.title('Распределение заработной платы')
plt.xlabel('Заработная плата (руб)')
plt.ylabel('Частота')

# Коробчатая диаграмма
plt.subplot(1, 2, 2)
sns.boxplot(x=merged['ЗП (руб)'])
plt.title('Коробчатая диаграмма заработной платы')
plt.xlabel('Заработная плата (руб)')

plt.tight_layout()
plt.show()

# Вычисление статистик
min_salary = merged['ЗП (руб)'].min()        # Минимальное значение
max_salary = merged['ЗП (руб)'].max()        # Максимальное значение
q1 = merged['ЗП (руб)'].quantile(0.25)       # 1-й квартиль
q3 = merged['ЗП (руб)'].quantile(0.75)       # 3-й квартиль
iqr = q3 - q1                             # Интерквартильный размах

# Определение предельных значений для выявления аномалий
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# Интервал, в котором находится большинство соискателей
majority_salary_range = (q1, q3)

# Вывод результатов
print(f"Количествво соискателей, желающщих ЗП более 1 млн руб.: {merged[merged['ЗП (руб)'] > 1000000]['ЗП (руб)'].count()}")
print(f"Предельные значения заработной платы: {min_salary} - {max_salary} рублей")
print(f"Заработная плата большинства соискателей находится в интервале: {majority_salary_range} рублей")
print(f"Найдены аномалии: {merged[(merged['ЗП (руб)'] < lower_bound) | (merged['ЗП (руб)'] > upper_bound)]['ЗП (руб)'].value_counts()}")
# Out:
# Количествво соискателей, желающщих ЗП более 1 млн руб.: 5
# Предельные значения заработной платы: 1.0 - 24304876.0 рублей
# Заработная плата большинства соискателей находится в интервале: (37082.2, 95000.0) рублей
# Найдены аномалии: ЗП (руб)
# 200000.00    873
# 250000.00    476
# 300000.00    261
# 220000.00    141
# 350000.00    110
#             ...
# 325170.45      1
# 387102.60      1
# 337360.00      1
# 395000.00      1
# 222222.00      1
# Name: count, Length: 205, dtype: int64

# %% [markdown]
# # Выводы:
#
# * Желаемая зарплата соискателей находится в пределах 1 - 24 304 876 рублей.
# * Заработная плата, устраивающая большинство соискателей находится в интервале: 37 - 95 тыс. руб.
# * В распределении имеется значительное количество аномальных значений. Так, 5 человек желают ЗП более 1 млн. руб. Возможно, это связано с тем, что сам вопрос "какова ваша желаемая зарплата?" может быть понят неоднозначно. Конечно никто не отказался бы от 24 млн. руб. в месяц, но большинство понимает, что указывать надо ЗП в разумных пределах. Что такое "разумные пределы", как их определять, каждый решает по-своему. Вероятно поэтому, распределение зарплат отличается от распределения возраста и опыта большим количеством аномалий и большей асимметрией.
# * Зигзагообразная линия KDE может свидетельствовать о том, что данные имеют сложное распределение, которое не является гладким или указывать на наличие различных подгрупп в данных. Наличие выбросов или аномальных значений может также влиять на форму линии KDE. Если в данных есть значения, которые значительно отличаются от остальных, это может привести к искажению оценки плотности.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# Фильтрация данных: оставляем только записи с ЗП < 1 млн
filtered_df = merged[merged['ЗП (руб)'] < 1000000]

# Группировка данных и вычисление медианной ЗП по уровню образования
median_salary_by_education = filtered_df.groupby('Образование')['ЗП (руб)'].median().reset_index()

# Построение диаграммы
plt.figure(figsize=(10, 6))
sns.barplot(x='Образование', y='ЗП (руб)', data=median_salary_by_education, palette='viridis')
plt.title('Медианная желаемая заработная плата по уровню образования')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная ЗП (руб)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Выводы:
#
# Медианная желаемая зарплата зависит от уровня образования: с увеличением уровня образования, увеличивается и зарплата. Максимальная медианная желаемая зарплата наблюдается для высшего образования, минимальная - для среднего специального. При этом, различия для среднего и среднего специального образований несущественны.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# Построение диаграммы
plt.figure(figsize=(12, 6))
sns.boxplot(x='Город', y='ЗП (руб)', data=filtered_df, palette='viridis')
plt.title('Распределение желаемой заработной платы по городам')
plt.xlabel('Город')
plt.ylabel('Желаемая ЗП (руб)')
plt.xticks(rotation=45)
plt.show()
median_salary_million = filtered_df[filtered_df['Город'] == 'город-миллионник']['ЗП (руб)'].median()
median_salary_other = filtered_df[filtered_df['Город'] == 'город-миллионник']['ЗП (руб)'].median()
print(f"Медианная желаемая ЗП для городов - миллионников {median_salary_million:,.0f} руб.")
print(f"Медианная желаемая ЗП для городов из категории 'другие' {median_salary_other:,.0f} руб.")
# Out:
# Медианная желаемая ЗП для городов - миллионников 40,000 руб.
# Медианная желаемая ЗП для городов из категории 'другие' 40,000 руб.

# %% [markdown]
# # Выводы:
#
# * Медианное значение желаемых зарплет тем выше, чем значимее город. Так наибольшие значения наблюдаются для Москвы, затем идет Санкт-Петербург.
# * Не зная распределения, можно предположить, что для городов миллионников, уровень желаемой зарплаты выше, чем для менее крупных городов. Однако это не так.
# * Не совсем понятна ситуация с разбросом. На первый взгляд кажется, что самый высокий разброс у категории "другие". Однако, бОльшая часть точек выбросов расположена плотно рядом с усами и, если исключить относительно небольшое количество экстремальных значений, получим кактину, такую же как и для городов-миллионников. Из остальных категорий самый большой разброс у Москвы, потом у Санкт-Петербурга, а самый низкий у городов-миллионников.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# Группировка данных и вычисление медианной ЗП
median_salary = merged.groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().reset_index()

# Построение многоуровневой столбчатой диаграммы
plt.figure(figsize=(10, 6))
sns.barplot(x='Готовность к переезду', y='ЗП (руб)', hue='Готовность к командировкам', data=median_salary, palette='viridis')
plt.title('Медианная заработная плата в зависимости от готовности к переезду и командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная ЗП (руб)')
plt.legend(title='Готовность к командировкам')
plt.show()

# Фильтрация данных: готовность к переезду и командировкам
filtered_df = merged[(merged['Готовность к переезду'] == True) & (merged['Готовность к командировкам'] == True)]

# Вычисление медианной заработной платы
filtered_df_median_salary = filtered_df['ЗП (руб)'].median()

# Приведение к тысячам и округление
median_salary_thousands = round(filtered_df_median_salary / 1000)

# Вывод результата
print(f'Медианная заработная плата соискателей, готовых и к переезду, и к командировкам {median_salary_thousands} тыс. руб.')
# Out:
# Медианная заработная плата соискателей, готовых и к переезду, и к командировкам 66 тыс. руб.

# %% [markdown]
# # Выводы
#
# Медианная желаемая ЗП возрастает, если соискатель готов к переездам или к командировкам. Влияние на медианную ЗП готовности к командировкам больше чем готовности к переездам.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# Создание сводной таблицы
pivot_table = merged.pivot_table(values='ЗП (руб)', index='Возраст', columns='Образование', aggfunc='median')

# Построение тепловой карты
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap='viridis', cbar_kws={'label': 'Медианная ЗП (руб)'})
plt.title('Тепловая карта медианной желаемой заработной платы по возрасту и образованию')
plt.xlabel('Уровень образования')
plt.ylabel('Возраст (лет)')
plt.show()

# %% [markdown]
# # Выводы:
#
# Тепловая карта позволяет быстро оценить, как медианная желаемая заработная плата варьируется в зависимости от возраста и уровня образования. Более яркие (или темные) ячейки указывают на более высокие значения заработной платы.
#
# * Влияние образования: можно заметить, что соискатели с высшим образованием, как правило, имеют более высокую медианную заработную плату по сравнению с остальными группами. Об этом можно судить по более светлыми оттенкам в левом столбце. Нсколько меньшая медианная заработная плата характерна для неоконченного высшего образования и далее идут среднее и средне специальное образования (темно-зеленые и синие тона).
#
# * Возрастные группы: Также можно увидеть, что набольшие желаемые зарплаты сосредоточены в центре (для всех групп образования). То есть, желаемая медианная зарплата с возрастом сначала возрастает, достигая максимальных значений к 40 - 45 годам, а затем начинает снижаться.

# %% [markdown]
# 8. Постройте диаграмму рассеяния, показывающую зависимость опыта работы («Опыт работы (месяц)») от возраста («Возраст»). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе.
# Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше неё, — аномалии в наших данных (опыт работы больше либо равен возрасту соискателя).

# %%
# Перевод опыта работы из месяцев в годы
experience_month = merged['Опыт работы (месяц)'] / 12

# Построение диаграммы рассеяния
plt.figure(figsize=(10, 6))
plt.scatter(merged['Возраст'], experience_month, color='blue', label='Данные')

# Добавление прямой y = x
plt.plot([0, 100], [0, 100], color='red', linestyle='--', label='Опыт = Возраст')

# Настройка графика
plt.title('Зависимость опыта работы от возраста')
plt.xlabel('Возраст (лет)')
plt.ylabel('Опыт работы (лет)')
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.axhline(0, color='black',linewidth=0.5, ls='--')
plt.axvline(0, color='black',linewidth=0.5, ls='--')
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()
plt.show()

# Фильтрация данных: точки выше прямой
above_line = merged[experience_month > merged['Возраст']]

# Количество точек выше прямой
count_above_line = above_line.shape[0]
print(f'Количество точек, лежащих строго выше прямой: {count_above_line}')
print('Наблюдения, лежащие выше прямой:')
display(above_line)
# Out:
# Количество точек, лежащих строго выше прямой: 7
# Наблюдения, лежащие выше прямой:
#              Ищет работу на должность:  \
# 4535            Технический специалист
# 19351  Специалист (Junior-программист)
# 19872                         Аналитик
# 26477             Менеджер IT-проектов
# 29098      Ведущий инженер-программист
# 40015  Системный администратор Windows
# 43451   Руководитель отдела разработки
#
#                          Последнее/нынешнее место работы  \
# 4535                                                   а
# 19351                                  Русский свет, ООО
# 19872                                           Kyivstar
# 26477  М©й IT'M  ("Информационные Технологии' Менеджм...
# 29098                           КБ Аметист, Концерн АГАТ
# 40015                                     АО ТК Горизонт
# 43451                                              ЛАНИТ
#
#                      Последняя/нынешняя должность   Обновление резюме  \
# ...

# %% [markdown]
# # Выводы:
#
# Точки, которые находятся выше красной линии, указывают на аномалии в данных, где опыт работы больше или равен возрасту соискателя. Это может быть следствием ошибок в данных. Так, например, ведущий инженер-программист с индексом 29098 указывает возраст 14 лет. Покольку все остальные сведения для данной записи вполне корректны, можно предположить опечатку по невнимательности.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# Группировка данных и вычисление медианной ЗП
median_salary = filtered_df.groupby('Пол')['ЗП (руб)'].median().reset_index()

# Построение диаграммы
plt.figure(figsize=(8, 5))
sns.barplot(x='Пол', y='ЗП (руб)', data=median_salary, palette='viridis')
plt.title('Медианная желаемая заработная плата по полу')
plt.xlabel('Пол')
plt.ylabel('Медианная ЗП (руб)')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Выводы:
#
# Интересно посмотреть на зависимость желаемой медианной зарплаты от пола соискателей. Здесь интерес представляет вопрос не "у кого больше" (это и так понятно), а насколько больше. Расхождение небольшое, около 15 %, но хотелось бы чтобы его не было вообще.

# %%
# Создание списка типов занятости
employment_types = [
    'полная занятость', 'частичная занятость', 'проектная работа',
    'стажировка', 'волонтерство', 'полный день', 'сменный график',
    'гибкий график', 'удаленная работа', 'вахтовый метод'
]

# Вычисление медианной ЗП для каждого типа занятости
median_salaries = []
for employment in employment_types:
    median_salary = filtered_df[filtered_df[employment]]['ЗП (руб)'].median()
    median_salaries.append(median_salary)

# Создание DataFrame для медианных зарплат
median_salary_df = pd.DataFrame({
    'Тип занятости': employment_types,
    'Медианная ЗП (руб)': median_salaries
})

# Построение диаграммы
plt.figure(figsize=(12, 6))
sns.barplot(x='Тип занятости', y='Медианная ЗП (руб)', data=median_salary_df, palette='viridis')
plt.title('Медианная желаемая заработная плата по типу занятости')
plt.xlabel('Тип занятости')
plt.ylabel('Медианная ЗП (руб)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Выводы:
#
# * Как и следовало ожидать, на максимальную зарплату претендуют соискатели на проектную работы (где требуется очень высокая квалификация) и на полную занатость (вероятно это то же самое, что и "полный день, на диаграмме высота столбцов для них почти одинакова).
# * Далее следуют "удаленная работа", "гибкий график" и "частичная занятость" их медианная желаемая зарплата меньше на 10 - 15%. Здесь все понятно, меньше работы - меньше зарплата.
# * Затем идут сменный график и вахтовый метод. Эта группа претендует на меньшую зарплату, но причина неочевидна. Вроде бы, сменная работа по времени, проведенном на рабочем месте сопоставима с полной занятостью. Может быть это связано с тем, что соответствующие рабочие места не требуют высокой квалификации.
# * Самые низкие зарплаты характерны для стажировки (то есть для соискателей без опыта) и волонтерства (разовые работы). Здесь тоже все ясно.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# Выводим количество строк до удаления дубликатов
print("Количество строк до удаления дубликатов:", len(merged))

# Удаление полных дубликатов
df_cleaned = merged.drop_duplicates()

# Выводим количество строк после удаления дубликатов
print("Количество строк после удаления дубликатов:", len(df_cleaned))

# Выводим количество удаленных строк
print("Количество удаленных дубликатов:", len(merged) - len(df_cleaned))

# Подсчет количества полных дубликатов
num_duplicates = df.duplicated().sum()

# Вывод количества полных дубликатов
print(f'Количество полных дубликатов: {num_duplicates}')

# Выводим очищенный DataFrame
display(df_cleaned.head())
# Out:
# Количество строк до удаления дубликатов: 44744
# Количество строк после удаления дубликатов: 44586
# Количество удаленных дубликатов: 158
# Количество полных дубликатов: 158
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность   Обновление резюме  \
# 0                           Системный администратор 2019-04-16 15:59:00
# 1  Менеджер проекта, Аналитик, Технический писатель 2019-04-12 08:42:00
# ...

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# Вывод информации о числе пропусков в столбцах
missing_values = merged.isnull().sum()

# Вывод результата
print("Количество пропусков в столбцах:")
print(missing_values)
# Out:
# Количество пропусков в столбцах:
# Ищет работу на должность:            0
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Обновление резюме                    0
# Авто                                 0
# Образование                          0
# Пол                                  0
# Возраст                              0
# Опыт работы (месяц)                168
# Город                                0
# Готовность к переезду                0
# Готовность к командировкам           0
# полная занятость                     0
# частичная занятость                  0
# проектная работа                     0
# волонтерство                         0
# стажировка                           0
# полный день                          0
# сменный график                       0
# гибкий график                        0
# удаленная работа                     0
# вахтовый метод                       0
# ЗП (руб)                             0
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Удаление строк с пропусками в столбцах "Последнее/нынешнее место работы" и "Последняя/нынешняя должность"
df_cleaned = df_cleaned.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

# Заполнение пропусков в столбце "Опыт работы (месяц)" медианным значением
median_experience = df_cleaned['Опыт работы (месяц)'].median()
df_cleaned['Опыт работы (месяц)'].fillna(median_experience, inplace=True)

# Удаление строк с пропусками в столбцах "Последнее/нынешнее место работы" и "Последняя/нынешняя должность"
df_cleaned = df_cleaned.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

# Заполнение пропусков в столбце "Опыт работы (месяц)" медианным значением
median_experience = df_cleaned['Опыт работы (месяц)'].median()
df_cleaned['Опыт работы (месяц)'].fillna(median_experience, inplace=True)

# Выводим информацию об очищенном DataFrame
print(df_cleaned.info())

# Выводим Среднее значение опыта работы
print(f'Среднее значение опыта работы {df_cleaned["Опыт работы (месяц)"].mean():.0f} мес.')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44584 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44584 non-null  object
#  1   Последнее/нынешнее место работы  44584 non-null  object
#  2   Последняя/нынешняя должность     44584 non-null  object
#  3   Обновление резюме                44584 non-null  datetime64[ns]
#  4   Авто                             44584 non-null  object
#  5   Образование                      44584 non-null  object
#  6   Пол                              44584 non-null  object
#  7   Возраст                          44584 non-null  int64
#  8   Опыт работы (месяц)              44584 non-null  float64
#  9   Город                            44584 non-null  object
#  10  Готовность к переезду            44584 non-null  bool
#  11  Готовность к командировкам       44584 non-null  bool
# ...

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# Удаление резюме с ЗП выше 1 млн или ниже 1 тыс.
df_cleaned = df_cleaned[(df_cleaned['ЗП (руб)'] <= 1000000) & (df_cleaned['ЗП (руб)'] >= 1000)]

# Выводим очищенный DataFrame
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44495 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44495 non-null  object
#  1   Последнее/нынешнее место работы  44495 non-null  object
#  2   Последняя/нынешняя должность     44495 non-null  object
#  3   Обновление резюме                44495 non-null  datetime64[ns]
#  4   Авто                             44495 non-null  object
#  5   Образование                      44495 non-null  object
#  6   Пол                              44495 non-null  object
#  7   Возраст                          44495 non-null  int64
#  8   Опыт работы (месяц)              44495 non-null  float64
#  9   Город                            44495 non-null  object
#  10  Готовность к переезду            44495 non-null  bool
#  11  Готовность к командировкам       44495 non-null  bool
# ...

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# Определяем количество записей в DataFrame до удаления выбросов
df_cleaned_before = df_cleaned.shape[0]

# Удаление резюме, где опыт работы в годах превышает возраст
df_cleaned = df_cleaned[df_cleaned['Опыт работы (месяц)'] / 12 <= df_cleaned['Возраст']]

# Определяем количество записей в DataFrame после удаления выбросов
df_cleaned_after = df_cleaned.shape[0]

# Выводим количество удаленных записей
print(f'Найдено выбросов {df_cleaned_before - df_cleaned_after}')
# Out:
# Найдено выбросов 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# Применяем логарифмическое преобразование к возрасту
df_cleaned['log_Возраст'] = np.log(df_cleaned['Возраст'])

# Построение гистограммы
plt.figure(figsize=(10, 6))
histplot = sns.histplot(df_cleaned['log_Возраст'], bins=10, kde=True)

# Добавление линии среднего
mean_log_age = df_cleaned['log_Возраст'].mean()
histplot.axvline(mean_log_age, color='k', lw=2, label='Среднее')

# Вычисление границ интервала метода трех сигм
std_log_age = df_cleaned['log_Возраст'].std()
lower_bound = mean_log_age - 3 * std_log_age
upper_bound = mean_log_age + 3 * std_log_age
upper_bound_4 = mean_log_age + 4 * std_log_age  # "послабление" на 1 сигму
histplot.axvline(lower_bound, color='r', linestyle='--', lw=2, label='3 сигмы (нижняя граница)')
histplot.axvline(upper_bound, color='r', linestyle='--', lw=2, label='3 сигмы (верхняя граница)')
histplot.axvline(upper_bound_4, color='g', linestyle='--', lw=2, label='4 сигмы (верхняя граница)')

# Настройка графика
plt.title('Распределение возраста в логарифмическом масштабе')
plt.xlabel('Логарифм возраста')
plt.ylabel('Частота')
plt.legend()
plt.grid()
plt.show()

# Поиск выбросов с помощью метода z-отклонения
df_cleaned['z_score'] = (df_cleaned['log_Возраст'] - mean_log_age) / std_log_age
outliers = df_cleaned[(df_cleaned['z_score'] > 4) | (df_cleaned['z_score'] < -3)]  # Используем 3 сигмы слева и 4 сигмы справа для поиска выбросов

# Вывод таблицы с выбросами
print("Выбросы:")
display(outliers)

# Количество выбросов
num_outliers = outliers.shape[0]
print(f'Количество выбросов: {num_outliers}')


# Удаление выбросов
df_cleaned = df_cleaned[(df_cleaned['z_score'] <= 4) & (df_cleaned['z_score'] >= -3)]
df_cleaned.drop('z_score', axis=1, inplace=True)

# Смотрим, что получилось
print(df_cleaned.info())
# Out:
# Выбросы:
#             Ищет работу на должность: Последнее/нынешнее место работы  \
# 31137  Менеджер по работе с клиентами           ООО "ФёрстКэшКомпани"
# 32950                 Тестировщик игр                        OOO ЖМЫХ
# 33654            Frontend-разработчик                       Freelance
#
#          Последняя/нынешняя должность   Обновление резюме        Авто  \
# 31137  Менеджер по работе с клиентами 2019-04-06 09:13:00  Не указано
# 32950                  Тестировщик ПО 2019-04-09 16:02:00  Не указано
# 33654            Frontend-разработчик 2019-04-19 23:27:00  Не указано
#
#                Образование Пол  Возраст  Опыт работы (месяц)            Город  \
# 31137              среднее   М       15                  2.0  Санкт-Петербург
# 32950  среднее специальное   М       15                  3.0           другие
# 33654  среднее специальное   М      100                 30.0  Санкт-Петербург
#
#        ...  волонтерство  стажировка  полный день  сменный график  \
# ...

# %% [markdown]
# # Выводы:
#
# Переход к логарифмической шкале позволил сделать распределение более похожим на нормальное. Насколько оно близко, можно выяснить при помощи критерия согласия. Во всяком случае логарифмический масштаб лучше подходит для определения выбросов при помощи z- оценок. Был обнаружен один выброс справа, для 100-летнего соискателя. Этот вывод совпадает со сделанным ранее. кроме того найдены два выброса слева. Обнаруженные выбросы удалены.
